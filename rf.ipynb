# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor as rf

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
# Obtain target and predictors
y = train.SalePrice
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = train[features].copy()
X_test = test[features].copy()

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,train_size=0.8,random_state=42)

# %%
x_train.head()
# Out:
#       LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 254      8400       1957      1314         0         1             3
# 1066     7837       1993       799       772         2             3
# 638      8777       1910       796         0         1             2
# 799      7200       1937       981       787         1             3
# 380      5000       1924      1026       665         2             3
#
#       TotRmsAbvGrd
# 254              5
# 1066             7
# 638              4
# 799              7
# 380              6

# %%
model_1 = rf(n_estimators = 50, random_state=0)
model_2 = rf(n_estimators=100, random_state=0)
model_3 = rf(n_estimators=100, criterion='mae', random_state=0)
model_4 = rf(n_estimators=200, min_samples_split=20, random_state=0)
model_5 = rf(n_estimators=100, max_depth=7, random_state=0)

models = [model_1, model_2, model_3, model_4, model_5]

# %%
from sklearn.metrics import mean_absolute_error 
def score_model(model, X_t=x_train, X_v=x_test, y_t=y_train, y_v=y_test):
    model.fit(X_t, y_t)
    preds = model.predict(X_v)
    return mean_absolute_error(y_v, preds)

for i in range(0, len(models)):
    mae = score_model(models[i])
    print("Model %d MAE: %d" % (i+1, mae))
# Out:
# Model 1 MAE: 22325
# Model 2 MAE: 22435
# Model 3 MAE: 22666
# Model 4 MAE: 22915
# Model 5 MAE: 22901

# %%
best_model = model_3

# %%
my_model = best_model

# %%
my_model.fit(X,y)
# Out:
# RandomForestRegressor(criterion='mae', random_state=0)

# %%
pred = my_model.predict(x_test)
print(pred)
# Out:
# [148845.    324439.1   107355.86  148562.18  298515.9    77184.
#  265176.32  146341.5    85649.    132789.    143080.5   126702.5
#  100932.    216797.8   181499.32  124435.36  196102.    134226.58
#  106673.6   227157.22  176731.    204081.85  176144.15  123808.5
#  189700.79  164036.    191797.78  127092.5   178962.    207183.35
#  118574.    271464.    212206.24  129835.01  265411.92  137750.87
#  146252.5   218290.35  317702.19  108592.    114216.    220917.9
#  123509.5   305783.43  128781.    132630.58  120173.5   124134.5
#  439926.51  144501.5   118195.    192808.5   118967.54  272986.24
#  145710.5   275115.03  201497.32  169140.64  118357.87  113378.5
#   72079.22  150329.87  313215.63  268297.94  315639.19  215404.
#  106924.5   302409.3   109836.    173469.    122852.56  138177.74
#  112557.28   92953.93  556827.46  182132.06  328673.5   312495.
#  140256.87  126414.6   101952.5    84105.8   123021.5    98121.
# ...

# %%
output = pd.DataFrame({'Id':x_test.index,
                      'SalePrice ':pred})

output.to_csv("submission.csv",index = False)

# %%
# Get names of columns with missing values
cols_with_missing = [col for col in x_train.columns
                     if x_train[col].isnull().any()]

# %%
# Drop columns in training and validation data
reduced_X_train = x_train.drop(cols_with_missing, axis=1)
reduced_X_valid = x_test.drop(cols_with_missing, axis=1)
